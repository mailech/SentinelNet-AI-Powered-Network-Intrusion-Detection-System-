# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder, OneHotEncoder, PowerTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold
# from sklearn.feature_selection import SelectKBest, chi2, f_classif, RFE, MutualInfoClassifier
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier, IsolationForest
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer, KNNImputer

# %%
# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Plot styling
plt.style.use('ggplot')
sns.set_palette("husl")

# Define Column Names for NSL-KDD (Standard List)
COL_NAMES = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label", "difficulty_level"]
# Load Data (Assuming data is in ../SentinelNet/data or ../data relative to notebook)
# You might need to adjust the path based on your exact folder structure
train_path = './data/KDDTrain+.txt'
test_path = './data/KDDTest+.txt'

# Try loading with error handling for paths
try:
    df_train = pd.read_csv(train_path, header=None, names=COL_NAMES)
    df_test = pd.read_csv(test_path, header=None, names=COL_NAMES)
    print(f"Training Data Shape: {df_train.head()}")
    print(f"Test Data Shape: {df_test.tail()}")
except FileNotFoundError:
    print("Files not found. Please check the paths. Trying absolute paths or checking local directory...")
    # Fallback to local directory if paths are different
    if os.path.exists('KDDTrain+.txt'):
        df_train = pd.read_csv('KDDTrain+.txt', header=None, names=COL_NAMES)
        df_test = pd.read_csv('KDDTest+.txt', header=None, names=COL_NAMES)

# Combine for initial analysis (optional, but good for understanding full global distributions)
# We will split back later to avoid data leakage.
# For rigorous preprocessing, we fit on TRAIN and transform TEST.
# Out:
# Training Data Shape:    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#      label  difficulty_level
# 0   normal                20
# 1   normal                15
# 2  neptune                19
# 3   normal                21
# 4   normal                21
#
# [5 rows x 43 columns]
# Test Data Shape:        duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 22539         0           tcp      smtp   SF        794        333     0
# 22540         0           tcp      http   SF        317        938     0
# 22541         0           tcp      http   SF      54540       8314     0
# 22542         0           udp  domain_u   SF         42         42     0
# 22543         0           tcp    sunrpc  REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 22539               0       0    0  ...                    0.72
# 22540               0       0    0  ...                    1.00
# 22541               0       0    2  ...                    1.00
# 22542               0       0    0  ...                    0.99
# 22543               0       0    0  ...                    0.08
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 22539                    0.06                         0.01
# 22540                    0.00                         0.01
# 22541                    0.00                         0.00
# 22542                    0.01                         0.00
# 22543                    0.03                         0.00
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 22539                         0.01                  0.01
# 22540                         0.01                  0.01
# 22541                         0.00                  0.00
# 22542                         0.00                  0.00
# 22543                         0.00                  0.00
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 22539                       0.0                  0.00
# 22540                       0.0                  0.00
# 22541                       0.0                  0.07
# 22542                       0.0                  0.00
# 22543                       0.0                  0.44
#
#        dst_host_srv_rerror_rate   label  difficulty_level
# 22539                      0.00  normal                21
# 22540                      0.00  normal                21
# 22541                      0.07    back                15
# 22542                      0.00  normal                21
# 22543                      1.00   mscan                14
#
# [5 rows x 43 columns]

# %%
exclude_cols = df_['label','attack_class','difficulty_level','is_outlier']
exclude_cols

# %%
import os
import sklearn.ensemble import randomforestcalssifire
import sklearn.preprocessing import labelcoder

#Encoding of the target labels    data = y_resampled

var = labelencoder()
var.fit_transform(data)

#Train a light weight Random Forest

pareameter = randomforestcalssifire(n_estimators, random_state = 42, max_depth = 10)
pareameter.fit(X_resampled,data)

# series of importance

v = pd.series(labelencded data and the random forest data)
importance = v.sort_values(ascending = true or false)

#plot the top 25 or 50 geatures


#identify the low importance features

treshold value = 0.001 
# low_importance = importance < treshold

# %%
# T-SNE

form sklearn.mainfold import TSNE

smaplesize = 3000

rows = np.random.choice(smaplesize,replace=false)


x-smaple = X_resampled[rows]
y-sampled = y_resampled[rows]



print(---------------)

t = TSNE(n_components=2,perplexity=40,n_iter = 1000,learning_rate ='auto',init='pca',random_state=42)

var = t.fit_transform(x-smaple)

pd.dataframe({var[:,0],var[:,1],class = 'y_sample.values'


color = {'mention the colors'}


plt.figure....

for cls in tsne['class'].unique():
    tsne[class] = null
color = pallet.get(color,#B47t5)

                   plt.scatter()

# %%
# Pipeline

# Imputing -- Filling up the missing values
# Scaling -- Sizing everything to fit
# Feature Selection --


# Numeric Pipeline

# SimpleImputer(strategy='median')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       1 # Pipeline
#       2
#       3 # Imputing -- Filling up the missing values
#    (...)
#       7
#       8 # Numeric Pipeline
# ---> 10 SimpleImputer(strategy='median')
#
# NameError: name 'SimpleImputer' is not defined

# %%
# import all the libraries

import joblib 
prep = joblib.load(name of the variable that u have imported)

# %%
import os, joblib, warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest, RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_curve, auc, 
    precision_recall_curve, f1_score, accuracy_score
)
from sklearn.preprocessing import LabelEncoder

warnings.filterwarnings('ignore')
plt.style.use('ggplot')
sns.set_palette("coolwarm")

# --- 1. DEFINE CUSTOM FUNCTION (REQUIRED FOR JOBLIB) ---
# You must define this here because the saved pipeline depends on it
def sentinel_engineer_features(X):
    """Calculates domain-specific network features."""
    X_out = X.copy()
    # Packet Rate (Avoid div by zero)
    X_out['packet_rate'] = X_out['count'] / (X_out['duration'] + 1e-5)
    # Byte Ratio
    total_bytes = X_out['src_bytes'] + X_out['dst_bytes']
    X_out['src_bytes_ratio'] = X_out['src_bytes'] / (total_bytes + 1e-5)
    # Service Interaction
    X_out['srv_interaction'] = X_out['same_srv_rate'] * X_out['dst_host_same_srv_rate']
    return X_out

# ─── 2. Load Preprocessing Engine ─────────────────────────────────────────────
# Updated paths to ensure they point to the files in your current folder
PREP_PATH = './models/preprocessing_engine.joblib' 

if not os.path.exists(PREP_PATH):
    # Fallback to absolute/user folder if the relative path fails
    PREP_PATH = r'c:\Users\SRIDHAR RAO\OneDrive\Desktop\Batch 1\models\preprocessing_engine.joblib'

if not os.path.exists(PREP_PATH):
    raise FileNotFoundError(f"Missing file at: {PREP_PATH}")

print("Loading Preprocessing Engine...")
prep_engine = joblib.load(PREP_PATH)

# ─── 3. Load Raw Training Data ────────────────────────────────────────────────
COL_NAMES = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label", "difficulty_level"]

DATA_PATH = './data/KDDTrain+.txt'
if not os.path.exists(DATA_PATH):
    DATA_PATH = r'c:\Users\SRIDHAR RAO\OneDrive\Desktop\Batch 1\data\KDDTrain+.txt'

df_raw = pd.read_csv(DATA_PATH, header=None, names=COL_NAMES)
print(f" Engine Loaded. Ready to process {df_raw.shape[0]} raw connections.")
# Out:
# Loading Preprocessing Engine...
#  Engine Loaded. Ready to process 125973 raw connections.

# %%
# Mapping for the target variable (Only part not inside Pipeline)
attack_mapping = {
    'normal': 'normal',
    'back': 'DoS', 'land': 'DoS', 'neptune': 'DoS', 'pod': 'DoS', 'smurf': 'DoS', 'teardrop': 'DoS',
    'satan': 'Probe', 'ipsweep': 'Probe', 'nmap': 'Probe', 'portsweep': 'Probe',
    'guess_passwd': 'R2L', 'ftp_write': 'R2L', 'imap': 'R2L', 'warezmaster': 'R2L', 'warezclient': 'R2L',
    'buffer_overflow': 'U2R', 'loadmodule': 'U2R', 'perl': 'U2R', 'rootkit': 'U2R'
}
df_raw['attack_class'] = df_raw['label'].map(lambda x: attack_mapping.get(x, 'other'))

# 1. Extract Target
le = LabelEncoder()
y_master = le.fit_transform(df_raw['attack_class'])

# 2. Extract Features & Transform
X_raw = df_raw.drop(columns=['label', 'attack_class', 'difficulty_level'])
X_signal = prep_engine.transform(X_raw)

print(f"--- Connection Architecture ---")
print(f"Pre-Selection Features: {X_raw.shape[1]}")
print(f"Post-Selection Signal:  {X_signal.shape[1]}")
# Out:
# --- Connection Architecture ---
# Pre-Selection Features: 41
# Post-Selection Signal:  61

# %%
print("### ANALYZING NORMALCY BASELINES ###")

# A. Isolation Forest (The Outlier Expert)
iso = IsolationForest(contamination=0.03, random_state=42)
df_raw['iso_score'] = iso.fit_predict(X_signal)
df_raw['is_anomaly'] = df_raw['iso_score'].map({1: 0, -1: 1})

# B. Local Outlier Factor (Density Specialist)
# LOF is expensive; we sample for visualization
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.05)
lof_labels = lof.fit_predict(X_signal[:5000])

# C. One-Class SVM (The Boundary King)
oc_svm = OneClassSVM(kernel='rbf', gamma=0.1, nu=0.05)
oc_svm.fit(X_signal[:5000]) # Training on sample to learn 'Normal'

# ── Visualization: Anomaly Detection Performance ──
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.violinplot(x='attack_class', y='iso_score', data=df_raw, palette='magma')
plt.axhline(0, color='red', linestyle='--')
plt.title('Isolation Scores by Attack Class (Below Red Line = Anomalous)')

plt.subplot(1, 2, 2)
sns.countplot(x='attack_class', hue='is_anomaly', data=df_raw)
plt.title('Anomaly Labels vs True Attack Categories')
plt.yscale('log')
plt.show()

print("Unsupervised Insight: DoS attacks have clear outlier signals, whereas U2R is much subtler.")
# Out:
# ### ANALYZING NORMALCY BASELINES ###
# Unsupervised Insight: DoS attacks have clear outlier signals, whereas U2R is much subtler.

# %%
# 1. Split into Train/Test
# IMPORTANT: Ensure X_signal and y_master were successfully created in the previous cells
X_train, X_test, y_train, y_test = train_test_split(
    X_signal, y_master, test_size=0.2, random_state=42, stratify=y_master
)

# ── GRID SEARCH: Optimizing the Detector ──
print("Starting Hyperparameter Optimization (Grid Search)...")

# Define the parameter grid correctly
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [10, 20],
    'min_samples_leaf': [1, 2]
}

# Initialize GridSearchCV
grid = GridSearchCV(
    RandomForestClassifier(random_state=42, n_jobs=-1, class_weight='balanced'), 
    param_grid, 
    cv=3, 
    scoring='f1_macro', 
    verbose=1
)

# Fit the model
grid.fit(X_train, y_train)

# Extract best results
print(f" BEST HYPERPARAMETERS: {grid.best_params_}")
sentinel_brain = grid.best_estimator_
# Out:
# Starting Hyperparameter Optimization (Grid Search)...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
#  BEST HYPERPARAMETERS: {'max_depth': 20, 'min_samples_leaf': 2, 'n_estimators': 50}

# %%
y_pred = sentinel_brain.predict(X_test)
y_prob = sentinel_brain.predict_proba(X_test)

# 1. Confusion Matrix (The Map of Mistakes)
plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', 
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Threat Detection: Confusion Matrix')
plt.xlabel('Predicted by Sentinel')
plt.ylabel('Ground Truth')
plt.show()

# 2. Multi-Class ROC Curves
plt.figure(figsize=(12, 7))
for i in range(len(le.classes_)):
    fpr, tpr, _ = roc_curve(y_test == i, y_prob[:, i])
    plt.plot(fpr, tpr, lw=2, label=f'Class: {le.classes_[i]} (Area = {auc(fpr, tpr):.3f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('Receiver Operating Characteristic (ROC) Deep Dive')
plt.xlabel('Security False Alarms (FPR)')
plt.ylabel('Catch Rate (TPR)')
plt.legend()
plt.show()

# 3. Final Performance Audit
print("=== SENTINEL INTELLIGENCE PERFORMANCE AUDIT ===")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# === SENTINEL INTELLIGENCE PERFORMANCE AUDIT ===
#               precision    recall  f1-score   support
#
#          DoS       1.00      1.00      1.00      9186
#        Probe       1.00      1.00      1.00      2331
#          R2L       0.94      0.96      0.95       196
#          U2R       0.67      0.80      0.73        10
#       normal       1.00      1.00      1.00     13469
#        other       0.00      0.00      0.00         3
#
#     accuracy                           1.00     25195
#    macro avg       0.77      0.79      0.78     25195
# weighted avg       1.00      1.00      1.00     25195
