# %%
import os
import requests

# %%
DATA_DIR = "data"
if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
URLS = {
    'KDDTrain+.txt' : 'https://raw.githubusercontent.com/defcom17/NSL_KDD/master/KDDTrain+.txt' ,
    'KDDTest+.txt' : 'https://raw.githubusercontent.com/defcom17/NSL_KDD/master/KDDTest+.txt'
}

def download_file(url, filename):
    localpath = os.path.join(DATA_DIR, filename)

    if os.path.exists(filename):
        print(f" File Found: {filename} already exists")
        return
    print(f" Downloading {filename}...")

    try:
        response = requests.get(url, stream = True)
        response.raise_for_status()

        with open(localpath, 'wb') as f:
            for chunk in response.iter_content(chunk_size = 8000):
                f.write(chunk)
        print(f" Successfully saved to {localpath}")

    except Exception as e:
        print(f" Failed to download {filename} : {e}")

# %%
for filename, url in URLS.items():
    download_file(url, filename)
print("\nAll Files should now be in 'data' folder")
# Out:
# ...
#  Successfully saved to data\KDDTrain+.txt
# ...
#  Successfully saved to data\KDDTest+.txt
#
# All Files should now be in 'data' folder

# %%
import pandas as pd
import os

# Define the path to your data
DATA_DIR = 'data'
TRAIN_PATH = os.path.join(DATA_DIR, 'KDDTrain+.txt')

# Define the standard column names for the NSL-KDD dataset
COLUMNS = [
    "duration", "protocol_type", "service", "flag", "src_bytes", "dst_bytes", 
    "land", "wrong_fragment", "urgent", "hot", "num_failed_logins", 
    "logged_in", "num_compromised", "root_shell", "su_attempted", "num_root", 
    "num_file_creations", "num_shells", "num_access_files", "num_outbound_cmds", 
    "is_host_login", "is_guest_login", "count", "srv_count", "serror_rate", 
    "srv_serror_rate", "rerror_rate", "srv_rerror_rate", "same_srv_rate", 
    "diff_srv_rate", "srv_diff_host_rate", "dst_host_count", "dst_host_srv_count", 
    "dst_host_same_srv_rate", "dst_host_diff_srv_rate", "dst_host_same_src_port_rate", 
    "dst_host_srv_diff_host_rate", "dst_host_serror_rate", "dst_host_srv_serror_rate", 
    "dst_host_rerror_rate", "dst_host_srv_rerror_rate", "class", "difficulty_level"
]

# Read the dataset
# header=None tells pandas there is no header row in the file
# names=COLUMNS assign the column names we defined above
df = pd.read_csv(TRAIN_PATH, header=None, names=COLUMNS)

# Display the first few rows
df
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# ...

# %%
df.tail()
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 125968               0       0    0  ...                    0.10
# 125969               0       0    0  ...                    0.96
# 125970               0       0    0  ...                    0.12
# 125971               0       0    0  ...                    0.03
# 125972               0       0    0  ...                    0.30
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 125968                    0.06                         0.00
# ...

# %%
train_path = os.path.join(DATA_DIR, 'KDDTrain+.txt')
test_path = os.path.join(DATA_DIR, 'KDDTest+.txt')

# Read CSV with our column names
train_df = pd.read_csv(train_path, names=COLUMNS)
test_df = pd.read_csv(test_path, names=COLUMNS)

print("Data Loaded Successfully!")
# Out:
# Data Loaded Successfully!

# %%
LABELED_DIR = "labeled_data"

if not os.path.exists(LABELED_DIR):
    os.makedirs(LABELED_DIR)
train_df.to_csv(os.path.join(LABELED_DIR, "KDDTrain_data.csv"), index=False)
test_df.to_csv(os.path.join(LABELED_DIR, "KDDTest_data.csv"), index=False)

print("Processed datasets saved successfully!")
# Out:
# Processed datasets saved successfully!

# %%
print("\n---Data Info---")
train_df.info()
# Out:
# ---Data Info---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
# ...

# %%
print(f"Missing Values in teh Training Data: {train_df.isnull().sum().sum()}")
print(f"Missing Values in teh Testing Data: {test_df.isnull().sum()}")
# Out:
# Missing Values in teh Training Data: 0
# Missing Values in teh Testing Data: duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# ...

# %%
print(f"Duplicate data in the training dataset {train_df.duplicated().sum()}")
print(f"Duplicate data in the test dataset {test_df.duplicated()}")
# Out:
# Duplicate data in the training dataset 0
# Duplicate data in the test dataset 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22539    False
# 22540    False
# 22541    False
# 22542    False
# 22543    False
# Length: 22544, dtype: bool

# %%
train_df['class']
# Out:
# 0          normal
# 1          normal
# 2         neptune
# 3          normal
# 4          normal
#            ...
# 125968    neptune
# 125969     normal
# 125970     normal
# 125971    neptune
# 125972     normal
# Name: class, Length: 125973, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
unique_labels = train_df['class'].unique()
print(f" There are {len(unique_labels)} unique lables including 'normal'.")
print(unique_labels)
# Out:
#  There are 23 unique lables including 'normal'.
# ['normal' 'neptune' 'warezclient' 'ipsweep' 'portsweep' 'teardrop' 'nmap'
#  'satan' 'smurf' 'pod' 'back' 'guess_passwd' 'ftp_write' 'multihop'
#  'rootkit' 'buffer_overflow' 'imap' 'warezmaster' 'phf' 'land'
#  'loadmodule' 'spy' 'perl']

# %%
train_df['class'].value_counts()
# Out:
# class
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
train_df['class'].value_counts().plot(kind='bar')
plt.title("Attack Class Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
train_df['protocol_type'].unique()
# Out:
# array(['tcp', 'udp', 'icmp'], dtype=object)

# %%
train_df[(train_df['protocol_type'] == 'tcp') & (df['src_bytes']>500)]
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 42             2           tcp      smtp   SF       1591        372     0
# 60             0           tcp  ftp_data   SF        641          0     0
# 65             0           tcp      smtp   SF        696        333     0
# 95             2           tcp      smtp   SF       3065        331     0
# 111            0           tcp      smtp   SF       2089        335     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125944         1           tcp      smtp   SF       2049        362     0
# 125952         0           tcp      smtp   SF       1289        408     0
# 125957         1           tcp      smtp   SF       1247        327     0
# 125965         0           tcp      smtp   SF       2233        365     0
# 125970         0           tcp      smtp   SF       2231        384     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
subset = train_df[['duration','protocol_type','class']]
subset.head()

train_df['protocol_type'].unique()
# Out:
# array(['tcp', 'udp', 'icmp'], dtype=object)

# %%
tcp_traffic = train_df[train_df['protocol_type'] == 'tcp']
print(f"Traffic of the TCP Count is: {len(tcp_traffic)}")
# Out:
# Traffic of the TCP Count is: 102689

# %%
udp_traffic = train_df[train_df['protocol_type'] == 'udp']
print(f"Traffic of the UDP Count is: {len(udp_traffic)}")
# Out:
# Traffic of the UDP Count is: 14993

# %%
icmp_traffic = train_df[train_df['protocol_type'] == 'icmp']
print(f"Traffic of the UDP Count is: {len(icmp_traffic)}")
# Out:
# Traffic of the UDP Count is: 8291

# %%
train_df['land'].unique()
# Out:
# array([0, 1])

# %%
land_attack = train_df[train_df['land']==1]
print(f"Land attacks Found are: {len(land_attack)}")
# Out:
# Land attacks Found are: 25

# %%
first_30_rows = train_df.iloc[0:30]
first_30_rows
# Out:
#     duration protocol_type     service flag  src_bytes  dst_bytes  land  \
# 0          0           tcp    ftp_data   SF        491          0     0
# 1          0           udp       other   SF        146          0     0
# 2          0           tcp     private   S0          0          0     0
# 3          0           tcp        http   SF        232       8153     0
# 4          0           tcp        http   SF        199        420     0
# 5          0           tcp     private  REJ          0          0     0
# 6          0           tcp     private   S0          0          0     0
# 7          0           tcp     private   S0          0          0     0
# 8          0           tcp  remote_job   S0          0          0     0
# 9          0           tcp     private   S0          0          0     0
# 10         0           tcp     private  REJ          0          0     0
# 11         0           tcp     private   S0          0          0     0
# ...

# %%
train_df['service'].unique()
# Out:
# array(['ftp_data', 'other', 'private', 'http', 'remote_job', 'name',
#        'netbios_ns', 'eco_i', 'mtp', 'telnet', 'finger', 'domain_u',
#        'supdup', 'uucp_path', 'Z39_50', 'smtp', 'csnet_ns', 'uucp',
#        'netbios_dgm', 'urp_i', 'auth', 'domain', 'ftp', 'bgp', 'ldap',
#        'ecr_i', 'gopher', 'vmnet', 'systat', 'http_443', 'efs', 'whois',
#        'imap4', 'iso_tsap', 'echo', 'klogin', 'link', 'sunrpc', 'login',
#        'kshell', 'sql_net', 'time', 'hostnames', 'exec', 'ntp_u',
#        'discard', 'nntp', 'courier', 'ctf', 'ssh', 'daytime', 'shell',
#        'netstat', 'pop_3', 'nnsp', 'IRC', 'pop_2', 'printer', 'tim_i',
#        'pm_dump', 'red_i', 'netbios_ssn', 'rje', 'X11', 'urh_i',
#        'http_8001', 'aol', 'http_2784', 'tftp_u', 'harvest'], dtype=object)

# %%
print("\nAverage Duration by the Protocols")
print(train_df.groupby('protocol_type')['duration'].mean())
# Out:
# Average Duration by the Protocols
# protocol_type
# icmp      0.000000
# tcp     281.386419
# udp     485.372040
# Name: duration, dtype: float64

# %%
print("\nStatistics by protocol (Duration): ")
print(train_df.groupby('protocol_type')['duration'].agg(['min','max','count','mean']))
# Out:
# Statistics by protocol (Duration):
#                min    max   count        mean
# protocol_type
# icmp             0      0    8291    0.000000
# tcp              0  42908  102689  281.386419
# udp              0  29505   14993  485.372040

# %%
protocol_counts = train_df['protocol_type'].value_counts()
protocol_counts
# Out:
# protocol_type
# tcp     102689
# udp      14993
# icmp      8291
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

protocol_counts = train_df['protocol_type'].value_counts()
protocol_counts

def set_plot(title,xlabel,ylabel):
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
plt.figure(figsize=(8,4))
plt.bar(protocol_counts.index,protocol_counts.values,color = "red",edgecolor = "black")
set_plot("Traffic Volume by protocol","protocol","Count")
plt.show()

# %%
import seaborn as sns
small_bytes = df[df['src_bytes']<6000]
small_bytes

plt.figure(figsize = (8,4))
sns.histplot(small_bytes['src_bytes'],bins = 50, kde=True)
plt.title("Distribution of Source Bytes (>1500)")
plt.show()

# %%
plt.figure(figsize = (8,4))
small_bytes = train_df[train_df['src_bytes']<100000]

sns.boxplot(x = 'protocol_type',y = 'src_bytes',data = small_bytes)
plt.title("Source Byte outliers by teh protocols")
plt.show()

# %%
ct = pd.crosstab(train_df['protocol_type'],df['flag'])
ct
# Out:
# flag           OTH    REJ  RSTO  RSTOS0  RSTR     S0   S1   S2  S3     SF   SH
# protocol_type
# icmp             0      0     0       0     0      0    0    0   0   8291    0
# tcp             46  11233  1562     103  2421  34851  365  127  49  51661  271
# udp              0      0     0       0     0      0    0    0   0  14993    0

# %%
plt.figure(figsize=(12,5))
sns.heatmap(ct,annot = True, fmt='d', cmap='Blues')
plt.title("Protocol vs Connection Flag")
plt.show()

# %%
train_df.groupby('protocol_type')['src_bytes'].describe()
# Out:
#                   count          mean           std  min   25%   50%     75%  \
# protocol_type
# icmp             8291.0    342.577976  4.634674e+02  8.0   8.0  30.0  1032.0
# tcp            102689.0  55860.741861  6.501848e+06  0.0   0.0  12.0   292.0
# udp             14993.0     70.384913  8.317431e+01  1.0  42.0  44.0    86.0
#
#                         max
# protocol_type
# icmp           1.480000e+03
# tcp            1.379964e+09
# udp            5.160000e+02

# %%
train_df.groupby('protocol_type')['src_bytes'].apply(lambda x: (x == 0).sum())
# Out:
# protocol_type
# icmp        0
# tcp     49392
# udp         0
# Name: src_bytes, dtype: int64

# %%
zero_percentage = train_df.groupby('protocol_type')['src_bytes'].apply(
    lambda x: (x == 0).mean() * 100
)

print(zero_percentage)
# Out:
# protocol_type
# icmp     0.000000
# tcp     48.098628
# udp      0.000000
# Name: src_bytes, dtype: float64

# %%
train_df['src_bytes'].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df[train_df['src_bytes'] == 0]['class'].value_counts()
# Out:
# class
# neptune            41213
# normal              3415
# satan               2064
# portsweep           1894
# ipsweep              481
# nmap                 265
# land                  18
# warezmaster           18
# imap                   8
# buffer_overflow        8
# loadmodule             3
# multihop               2
# ftp_write              2
# rootkit                1
# Name: count, dtype: int64

# %%
df['class'].unique()
df['duration']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 125968    0
# 125969    8
# 125970    0
# 125971    0
# 125972    0
# Name: duration, Length: 125973, dtype: int64

# %%
fig, axes = plt.subplots(1,3, figsize=(10,5))
sns.countplot(x='protocol_type', data = df[df['class'] == 'phf'],ax= axes[0])
axes[0].set_title("Dos Attack Protocols")
sns.countplot(x='protocol_type', data = df[df['class'] == 'multihop'],ax= axes[1])
axes[1].set_title("PROBE Attack Protocols")
sns.countplot(x='protocol_type', data = df[df['class'] == 'normal'],ax= axes[2])
axes[2].set_title("Normal Traffic")

plt.tight_layout()
plt.show()

# %%
avg_distribution = df.groupby('class')['duration'].mean().sort_values()
avg_distribution
# Out:
# class
# land                  0.000000
# nmap                  0.000000
# pod                   0.000000
# smurf                 0.000000
# teardrop              0.000000
# neptune               0.000049
# satan                 0.127718
# back                  0.297071
# guess_passwd          2.716981
# ipsweep               3.616004
# phf                   4.500000
# imap                  6.545455
# warezmaster          15.050000
# ftp_write            32.375000
# loadmodule           36.222222
# perl                 41.333333
# buffer_overflow      91.700000
# rootkit             100.800000
# normal              168.587396
# multihop            184.000000
# spy                 318.000000
# warezclient         705.092135
# portsweep          8246.697032
# Name: duration, dtype: float64

# %%
avg_distribution = df.groupby('class')['duration'].mean().sort_values()
avg_distribution

avg_distribution.plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x = 'protocol_type',y='duration',hue='class', data = df)
plt.show()

# %%
import pandas as pd
import numpy as np
# Create log-transformed column
df['log_src_bytes'] = np.log1p(df['src_bytes'])  # log1p handles zero values
new_df = df[['duration', 'src_bytes', 'dst_bytes', 'count', 'srv_count', 'log_src_bytes']]
new_df.to_csv("new_dataset.csv", index=False)
print(new_df.head())
# Out:
#    duration  src_bytes  dst_bytes  count  srv_count  log_src_bytes
# 0         0        491          0      2          2       6.198479
# 1         0        146          0     13          1       4.990433
# 2         0          0          0    123          6       0.000000
# 3         0        232       8153      5          5       5.451038
# 4         0        199        420     30         32       5.298317

# %%
df['attack_flag'] = df['class'].apply(lambda x: 0 if x=='normal' else 1)

# %%
df[['duration','src_bytes','dst_bytes']].skew()
# Out:
# duration      11.880230
# src_bytes    190.669347
# dst_bytes    290.052911
# dtype: float64

# %%
#Check Class Distribution (Dataset Imbalance)
# Visualize how many samples belong to each class
plt.figure(figsize=(10,5))
sns.countplot(x='class', data=df)
plt.xticks(rotation=90)
plt.title("Class Distribution in NSL-KDD Dataset")
plt.show()

# %%
#Create Binary Attack Flag (Normal vs Attack)
# Create binary column: 0 = Normal, 1 = Attack
df['attack_flag'] = df['class'].apply(lambda x: 0 if x == 'normal' else 1)

# Visualize binary distribution
plt.figure(figsize=(6,4))
sns.countplot(x='attack_flag', data=df)
plt.title("Normal vs Attack Distribution")
plt.show()

# %%
#Analyze Protocol Type vs Attack Behavior
# Compare protocol distribution for normal vs attack
plt.figure(figsize=(8,5))
sns.countplot(x='protocol_type', hue='attack_flag', data=df)
plt.title("Protocol Type vs Attack")
plt.show()

# %%
# Examine src_bytes Distribution (Original)
# Visualize skewness in original src_bytes
plt.figure(figsize=(8,4))
sns.histplot(df['src_bytes'], bins=50)
plt.title("Original src_bytes Distribution")
plt.show()

# %%
# Apply log(1+x) transformation (handles zero values safely)
df['log_src_bytes'] = np.log1p(df['src_bytes'])

# Visualize transformed distribution
plt.figure(figsize=(8,4))
sns.histplot(df['log_src_bytes'], bins=50, kde=True, color='red')
plt.title("Log Transformed src_bytes Distribution")
plt.show()

# %%
# Analyze Zero src_bytes Behavior
# Create boolean column for zero src_bytes
df['zero_src_bytes'] = (df['src_bytes'] == 0)

# Visualize zero vs non-zero by attack flag
plt.figure(figsize=(6,4))
sns.countplot(x='zero_src_bytes', hue='attack_flag', data=df)
plt.title("Zero src_bytes vs Attack")
plt.show()

# %%
# Analyze Duration Across Classes
# Visualize duration distribution across classes
plt.figure(figsize=(10,5))
sns.boxplot(x='class', y='duration', data=df)
plt.xticks(rotation=90)
plt.title("Duration Distribution Across Classes")
plt.show()

# %%
# Protocol + Duration + Attack Relationship
# Multi-variable boxplot
plt.figure(figsize=(10,5))
sns.boxplot(x='protocol_type', y='duration', hue='attack_flag', data=df)
plt.title("Protocol vs Duration (Normal vs Attack)")
plt.show()

# %%
# Select important numerical features
numerical_cols = ['duration','src_bytes','dst_bytes','count','srv_count']

# Compute correlation matrix
corr = df[numerical_cols].corr()

# Visualize correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
# Compare Feature Means (Normal vs Attack)
# Compute mean values grouped by attack flag
mean_comparison = df.groupby('attack_flag')[numerical_cols].mean()

# Plot comparison
mean_comparison.T.plot(kind='bar', figsize=(10,5))
plt.title("Feature Means: Normal vs Attack")
plt.show()

# %%
dos = ['neptune','smurf','back','teardrop','pod','land']
probe = ['ipsweep','portsweep','nmap','satan']
r2l = ['guess_passwd','ftp_write','imap','phf','multihop','warezclient','warezmaster','spy']
u2r = ['buffer_overflow','rootkit','loadmodule','perl']

def attack_category(x):
    if x == 'normal':
        return 'Normal'
    elif x in dos:
        return 'DoS'
    elif x in probe:
        return 'Probe'
    elif x in r2l:
        return 'R2L'
    else:
        return 'U2R'

df['attack_category'] = df['class'].apply(attack_category)

# Visualize category distribution
plt.figure(figsize=(6,4))
sns.countplot(x='attack_category', data=df)
plt.title("Attack Category Distribution")
plt.show()
